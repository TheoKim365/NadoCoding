# %% [markdown]
# ## Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x00000287179802B0>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')
# c:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44733 (\N{HANGUL SYLLABLE GGEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac
matplotlib.rcParams['font.size'] = 15   # 글자 크기

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist  # 사용 가능한 폰트 목록
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['cmr10',
#  'DejaVu Serif Display',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'cmtt10',
#  'DejaVu Sans Display',
#  'cmsy10',
#  'cmmi10',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmss10',
#  'STIXGeneral',
#  'cmb10',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'Kunstler Script',
#  'Elephant',
#  'Goudy Old Style',
#  'Tw Cen MT',
#  'Comic Sans MS',
#  'Lucida Bright',
#  'Segoe UI',
#  'Calibri',
#  'Bodoni MT',
#  'Arial',
#  'Parchment',
#  'Franklin Gothic Demi',
#  'Trebuchet MS',
#  'Consolas',
#  'Microsoft PhagsPa',
#  'Rockwell Condensed',
#  'STLiti',
#  'Wide Latin',
#  'Palatino Linotype',
#  'Leelawadee UI',
#  'New Gulim',
#  'Elephant',
#  'HYGungSo-Bold',
#  'Bookman Old Style',
#  'HYShortSamul-Medium',
#  'Trebuchet MS',
#  'New Gulim',
#  'Lucida Sans',
#  'Arial',
#  'Bookman Old Style',
#  'Sitka',
#  'Segoe UI Emoji',
#  'Bodoni MT',
#  'Engravers MT',
#  'Harlow Solid Italic',
#  'Tw Cen MT',
#  'Verdana',
#  'Arial Rounded MT Bold',
#  'Showcard Gothic',
#  'Bodoni MT',
#  'Rockwell',
#  'Segoe UI',
#  'Garamond',
#  'Verdana',
#  'Constantia',
#  'Myanmar Text',
#  'Forte',
#  'Georgia',
#  'Calisto MT',
#  'Gill Sans MT',
#  'HYGothic-Extra',
#  'Californian FB',
#  'Maiandra GD',
#  'Microsoft JhengHei',
#  'Segoe Print',
#  'Calibri',
#  'Yu Gothic',
#  'Century Schoolbook',
#  'FZShuTi',
#  'Bahnschrift',
#  'STCaiyun',
#  'Magic R',
#  'Colonna MT',
#  'Mongolian Baiti',
#  'Dubai',
#  'Nirmala UI',
#  'Juice ITC',
#  'Segoe Print',
#  'Monotype Corsiva',
#  'Lucida Fax',
#  'Informal Roman',
#  'Maiandra GD',
#  'Forte',
#  'Comic Sans MS',
#  'Jokerman',
#  'Calisto MT',
#  'Verdana',
#  'Calisto MT',
#  'Segoe Script',
#  'Gill Sans MT',
#  'Nirmala UI',
#  'Garamond',
#  'Eras Light ITC',
#  'Snap ITC',
#  'French Script MT',
#  'Segoe UI',
#  'Microsoft YaHei',
#  'Microsoft JhengHei',
#  'Consolas',
#  'HYGraphic-Medium',
#  'Impact',
#  'Century',
#  'Agency FB',
#  'Arial',
#  'Haettenschweiler',
#  'Pristina',
#  'Candara',
#  'Malgun Gothic',
#  'Consolas',
#  'Lucida Sans',
#  'Yu Gothic',
#  'Lucida Fax',
#  'Calibri',
#  'Lucida Sans',
#  'Bookman Old Style',
#  'LiSu',
#  'Calibri',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Palatino Linotype',
#  'Perpetua',
#  'Batang',
#  'Bernard MT Condensed',
#  'Eras Demi ITC',
#  'Bookman Old Style',
#  'Corbel',
#  'HYGothic-Medium',
#  'Palatino Linotype',
#  'Niagara Engraved',
#  'Segoe UI',
#  'Trebuchet MS',
#  'Century Gothic',
#  'Headline R',
#  'Perpetua',
#  'Elephant',
#  'Franklin Gothic Book',
#  'Ink Free',
#  'Gabriola',
#  'Gloucester MT Extra Condensed',
#  'Cambria',
#  'Californian FB',
#  'Curlz MT',
#  'Eras Medium ITC',
#  'Palace Script MT',
#  'Book Antiqua',
#  'Segoe UI',
#  'Segoe UI Symbol',
#  'Microsoft Uighur',
#  'Bauhaus 93',
#  'Goudy Old Style',
#  'Bookman Old Style',
#  'Lucida Handwriting',
#  'Informal Roman',
#  'Bodoni MT',
#  'Franklin Gothic Demi',
#  'Calibri',
#  'Georgia',
#  'HYPost-Medium',
#  'Mistral',
#  'Perpetua',
#  'Segoe UI',
#  'Lucida Calligraphy',
#  'Chiller',
#  'HYPMokGak-Bold',
#  'Lucida Sans Typewriter',
#  'Bodoni MT',
#  'Rockwell Extra Bold',
#  'Poor Richard',
#  'Gill Sans MT',
#  'Berlin Sans FB',
#  'Georgia',
#  'SimSun-ExtB',
#  'Tahoma',
#  'Yet R',
#  'Verdana',
#  'MS Gothic',
#  'Segoe Print',
#  'Wingdings',
#  'Segoe UI',
#  'Playbill',
#  'Franklin Gothic Medium',
#  'Niagara Solid',
#  'Garamond',
#  'Century',
#  'Lucida Console',
#  'Corbel',
#  'Arial',
#  'Century Schoolbook',
#  'Gill Sans MT',
#  'Georgia',
#  'Webdings',
#  'Cambria',
#  'Lucida Handwriting',
#  'Yu Gothic',
#  'Century Gothic',
#  'Courier New',
#  'Times New Roman',
#  'Magneto',
#  'Segoe UI',
#  'Microsoft JhengHei',
#  'Sitka',
#  'Microsoft Sans Serif',
#  'Calibri',
#  'Nirmala UI',
#  'Bodoni MT',
#  'HYSinMyeongJo-Medium',
#  'Rockwell Condensed',
#  'Juice ITC',
#  'Gill Sans MT',
#  'Blackadder ITC',
#  'Eras Bold ITC',
#  'Dubai',
#  'Arial',
#  'Copperplate Gothic Light',
#  'Tahoma',
#  'Engravers MT',
#  'SimSun',
#  'Garamond',
#  'Candara',
#  'Bookshelf Symbol 7',
#  'Franklin Gothic Heavy',
#  'Goudy Old Style',
#  'Microsoft PhagsPa',
#  'Gill Sans MT Condensed',
#  'Californian FB',
#  'Vladimir Script',
#  'Californian FB',
#  'Book Antiqua',
#  'Rockwell',
#  'Arial',
#  'Berlin Sans FB',
#  'Corbel',
#  'Rage Italic',
#  'Bodoni MT',
#  'Javanese Text',
#  'High Tower Text',
#  'Pyunji R',
#  'Sitka',
#  'Stencil',
#  'Franklin Gothic Book',
#  'Lucida Bright',
#  'Gulim',
#  'Bradley Hand ITC',
#  'Eras Medium ITC',
#  'Segoe UI',
#  'Castellar',
#  'Comic Sans MS',
#  'Bookman Old Style',
#  'Bell MT',
#  'Trebuchet MS',
#  'Vivaldi',
#  'MS Gothic',
#  'Candara',
#  'Segoe MDL2 Assets',
#  'Franklin Gothic Medium Cond',
#  'Arial',
#  'Gill Sans Ultra Bold Condensed',
#  'Myanmar Text',
#  'Niagara Engraved',
#  'Castellar',
#  'Candara',
#  'Lucida Sans',
#  'Ebrima',
#  'High Tower Text',
#  'Palatino Linotype',
#  'Chiller',
#  'MV Boli',
#  'Trebuchet MS',
#  'Corbel',
#  'Gigi',
#  'Calibri',
#  'Rockwell',
#  'Copperplate Gothic Bold',
#  'Malgun Gothic',
#  'Jokerman',
#  'Wingdings 2',
#  'Freestyle Script',
#  'Segoe UI',
#  'Gigi',
#  'Verdana',
#  'Ravie',
#  'Showcard Gothic',
#  'Symbol',
#  'Courier New',
#  'Georgia',
#  'Goudy Old Style',
#  'Century Gothic',
#  'Gill Sans Ultra Bold',
#  'Wide Latin',
#  'Wingdings 3',
#  'Microsoft New Tai Lue',
#  'Wingdings 2',
#  'Lucida Bright',
#  'Microsoft YaHei',
#  'Franklin Gothic Demi Cond',
#  'Microsoft YaHei',
#  'Segoe UI Variable',
#  'Lucida Console',
#  'Candara',
#  'Segoe UI',
#  'Gill Sans MT Condensed',
#  'Arial',
#  'Magic R',
#  'Trebuchet MS',
#  'Calibri',
#  'Microsoft Tai Le',
#  'MoeumT R',
#  'Lucida Bright',
#  'Garamond',
#  'Segoe UI Historic',
#  'Lucida Fax',
#  'Ebrima',
#  'Franklin Gothic Medium',
#  'Goudy Stout',
#  'Nirmala UI',
#  'Bodoni MT',
#  'Microsoft JhengHei',
#  'Calisto MT',
#  'Calisto MT',
#  'Franklin Gothic Medium',
#  'Felix Titling',
#  'Palatino Linotype',
#  'Microsoft YaHei',
#  'Franklin Gothic Book',
#  'Tw Cen MT Condensed',
#  'Arial',
#  'Berlin Sans FB Demi',
#  'Malgun Gothic',
#  'Lucida Bright',
#  'MT Extra',
#  'Georgia',
#  'Bodoni MT',
#  'FZYaoTi',
#  'Lucida Sans Typewriter',
#  'Century Gothic',
#  'Trebuchet MS',
#  'Imprint MT Shadow',
#  'Microsoft Himalaya',
#  'STXingkai',
#  'Ravie',
#  'Niagara Solid',
#  'Leelawadee UI',
#  'French Script MT',
#  'Lucida Sans',
#  'Microsoft Uighur',
#  'Centaur',
#  'Candara',
#  'Comic Sans MS',
#  'Microsoft PhagsPa',
#  'Yu Gothic',
#  'STFangsong',
#  'Century Gothic',
#  'Gulim',
#  'Microsoft YaHei',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'Baskerville Old Face',
#  'Microsoft New Tai Lue',
#  'Dubai',
#  'Malgun Gothic',
#  'MS Reference Specialty',
#  'Wingdings 3',
#  'Mistral',
#  'YouYuan',
#  'HYPost-Medium',
#  'Palace Script MT',
#  'Bahnschrift',
#  'Times New Roman',
#  'Old English Text MT',
#  'Leelawadee UI',
#  'STHupo',
#  'Microsoft Tai Le',
#  'Lucida Sans',
#  'HYGraphic-Medium',
#  'Courier New',
#  'Consolas',
#  'Poor Richard',
#  'Times New Roman',
#  'Dubai',
#  'Matura MT Script Capitals',
#  'Monotype Corsiva',
#  'Bookman Old Style',
#  'Constantia',
#  'Papyrus',
#  'Batang',
#  'Tw Cen MT',
#  'Arial',
#  'Lucida Sans Typewriter',
#  'Comic Sans MS',
#  'Yu Gothic',
#  'Rockwell',
#  'Corbel',
#  'Footlight MT Light',
#  'MS Outlook',
#  'STXingkai',
#  'SimSun',
#  'Californian FB',
#  'OCR A Extended',
#  'Perpetua Titling MT',
#  'Microsoft Tai Le',
#  'Garamond',
#  'MS Outlook',
#  'Harlow Solid Italic',
#  'Constantia',
#  'Segoe Script',
#  'HYMyeongJo-Extra',
#  'Franklin Gothic Medium Cond',
#  'High Tower Text',
#  'Palatino Linotype',
#  'Times New Roman',
#  'Ami R',
#  'Leelawadee UI',
#  'Javanese Text',
#  'MS Reference Specialty',
#  'Stencil',
#  'Headline R',
#  'Colonna MT',
#  'Verdana',
#  'Calisto MT',
#  'Californian FB',
#  'Papyrus',
#  'Book Antiqua',
#  'Microsoft Yi Baiti',
#  'Rockwell Condensed',
#  'Gill Sans MT',
#  'Eras Bold ITC',
#  'Lucida Sans Typewriter',
#  'Constantia',
#  'Corbel',
#  'Times New Roman',
#  'Segoe UI',
#  'Nirmala UI',
#  'Segoe UI',
#  'Bodoni MT',
#  'Brush Script MT',
#  'Impact',
#  'Harrington',
#  'Century Gothic',
#  'Trebuchet MS',
#  'Segoe UI Historic',
#  'Segoe Fluent Icons',
#  'Bernard MT Condensed',
#  'Goudy Old Style',
#  'Onyx',
#  'Sylfaen',
#  'Calisto MT',
#  'Baskerville Old Face',
#  'Franklin Gothic Heavy',
#  'Gabriola',
#  'Calibri',
#  'Cambria',
#  'Viner Hand ITC',
#  'Matura MT Script Capitals',
#  'Corbel',
#  'Parchment',
#  'Algerian',
#  'Yu Gothic',
#  'Gadugi',
#  'Franklin Gothic Medium',
#  'Wingdings',
#  'MingLiU-ExtB',
#  'HYPost-Light',
#  'STFangsong',
#  'Comic Sans MS',
#  'Corbel',
#  'Old English Text MT',
#  'Segoe UI',
#  'Tahoma',
#  'Bell MT',
#  'Script MT Bold',
#  'Bell MT',
#  'Bodoni MT',
#  'Cambria',
#  'Bell MT',
#  'Georgia',
#  'HoloLens MDL2 Assets',
#  'MS Reference Sans Serif',
#  'Berlin Sans FB Demi',
#  'Tahoma',
#  'Pyunji R',
#  'YouYuan',
#  'Eras Light ITC',
#  'Gloucester MT Extra Condensed',
#  'HoloLens MDL2 Assets',
#  'MV Boli',
#  'STCaiyun',
#  'Microsoft Sans Serif',
#  'Felix Titling',
#  'Constantia',
#  'Courier New',
#  'Times New Roman',
#  'HYGothic-Medium',
#  'Haettenschweiler',
#  'Rockwell Condensed',
#  'Microsoft Himalaya',
#  'Book Antiqua',
#  'Tw Cen MT Condensed',
#  'Arial',
#  'Bodoni MT',
#  'Rage Italic',
#  'Book Antiqua',
#  'Comic Sans MS',
#  'Elephant',
#  'Constantia',
#  'Franklin Gothic Demi Cond',
#  'Magneto',
#  'Edwardian Script ITC',
#  'Onyx',
#  'HYGungSo-Bold',
#  'Bodoni MT',
#  'Times New Roman',
#  'Ebrima',
#  'SimSun-ExtB',
#  'Perpetua',
#  'Perpetua',
#  'Berlin Sans FB',
#  'Viner Hand ITC',
#  'HYHeadLine-Medium',
#  'Segoe MDL2 Assets',
#  'Gill Sans MT Ext Condensed Bold',
#  'Tw Cen MT Condensed Extra Bold',
#  'Century Schoolbook',
#  'Arial Rounded MT Bold',
#  'Lucida Fax',
#  'LiSu',
#  'Broadway',
#  'Segoe UI',
#  'Arial',
#  'Cooper Black',
#  'Freestyle Script',
#  'STXihei',
#  'FZYaoTi',
#  'HYPost-Light',
#  'Consolas',
#  'STLiti',
#  'Malgun Gothic',
#  'Gill Sans MT',
#  'Rockwell',
#  'Tempus Sans ITC',
#  'Franklin Gothic Book',
#  'Lucida Sans Typewriter',
#  'Eras Demi ITC',
#  'Kristen ITC',
#  'Centaur',
#  'Tw Cen MT Condensed',
#  'STKaiti',
#  'Symbol',
#  'Century Schoolbook',
#  'Sylfaen',
#  'Century Gothic',
#  'Segoe Print',
#  'Bookman Old Style',
#  'Candara',
#  'Yet R',
#  'Century Schoolbook',
#  'Bradley Hand ITC',
#  'Segoe UI',
#  'Copperplate Gothic Bold',
#  'Tw Cen MT',
#  'Microsoft Tai Le',
#  'STZhongsong',
#  'Segoe UI',
#  'Playbill',
#  'Bodoni MT',
#  'Segoe UI',
#  'Algerian',
#  'Lucida Sans Typewriter',
#  'Bell MT',
#  'Lucida Fax',
#  'Arial',
#  'Lucida Sans Unicode',
#  'Snap ITC',
#  'Tw Cen MT Condensed Extra Bold',
#  'Times New Roman',
#  'Candara',
#  'Tw Cen MT Condensed',
#  'Corbel',
#  'Berlin Sans FB',
#  'Vivaldi',
#  'Calibri',
#  'Courier New',
#  'High Tower Text',
#  'Calisto MT',
#  'Arial',
#  'Edwardian Script ITC',
#  'Myanmar Text',
#  'Verdana',
#  'Tw Cen MT',
#  'Corbel',
#  'Malgun Gothic',
#  'Agency FB',
#  'Century Schoolbook',
#  'Lucida Bright',
#  'Bodoni MT',
#  'Perpetua Titling MT',
#  'Candara',
#  'Nirmala UI',
#  'HYShortSamul-Medium',
#  'Corbel',
#  'Microsoft New Tai Lue',
#  'Rockwell Extra Bold',
#  'Perpetua Titling MT',
#  'Kunstler Script',
#  'Lucida Sans Typewriter',
#  'Perpetua Titling MT',
#  'Constantia',
#  'Consolas',
#  'Microsoft PhagsPa',
#  'Cooper Black',
#  'Candara',
#  'Microsoft YaHei',
#  'Franklin Gothic Heavy',
#  'Bell MT',
#  'Microsoft JhengHei',
#  'Franklin Gothic Demi',
#  'Segoe UI',
#  'Book Antiqua',
#  'Arial',
#  'Rockwell',
#  'Cambria',
#  'Leelawadee UI',
#  'Cambria',
#  'Britannic Bold',
#  'Segoe UI Emoji',
#  'Perpetua',
#  'Century Schoolbook',
#  'Goudy Stout',
#  'Segoe UI Symbol',
#  'OCR A Extended',
#  'MoeumT R',
#  'Constantia',
#  'Lucida Fax',
#  'Microsoft New Tai Lue',
#  'Lucida Fax',
#  'Palatino Linotype',
#  'Imprint MT Shadow',
#  'Ebrima',
#  'Tw Cen MT',
#  'STKaiti',
#  'Perpetua',
#  'Dubai',
#  'Segoe UI',
#  'Britannic Bold',
#  'HYPMokGak-Bold',
#  'Verdana',
#  'Gadugi',
#  'Franklin Gothic Demi',
#  'Microsoft Uighur',
#  'Gadugi',
#  'STZhongsong',
#  'Century Gothic',
#  'Agency FB',
#  'Consolas',
#  'Vladimir Script',
#  'STHupo',
#  'Calibri',
#  'Gill Sans Ultra Bold Condensed',
#  'Marlett',
#  'Brush Script MT',
#  'Bodoni MT',
#  'Segoe UI Variable',
#  'STSong',
#  'Agency FB',
#  'Rockwell',
#  'Pristina',
#  'Segoe Fluent Icons',
#  'MingLiU-ExtB',
#  'Lucida Sans',
#  'Lucida Calligraphy',
#  'Segoe UI',
#  'FZShuTi',
#  'Segoe UI',
#  'STXinwei',
#  'STXinwei',
#  'Lucida Sans Unicode',
#  'Cambria',
#  'Sitka',
#  'Arial',
#  'Tw Cen MT',
#  'Segoe Script',
#  'STXihei',
#  'MS Reference Sans Serif',
#  'Modern No. 20',
#  'HYMyeongJo-Extra',
#  'Modern No. 20',
#  'Candara',
#  'Microsoft Yi Baiti',
#  'Broadway',
#  'Corbel',
#  'Bodoni MT',
#  'Yu Gothic',
#  'Segoe Script',
#  'Arial',
#  'Yu Gothic',
#  'Mongolian Baiti',
#  'Myanmar Text',
#  'HYHeadLine-Medium',
#  'Harrington',
#  'HYGothic-Extra',
#  'Lucida Bright',
#  'Courier New',
#  'Webdings',
#  'Bodoni MT',
#  'Leelawadee UI',
#  'Rockwell',
#  'Tempus Sans ITC',
#  'Gill Sans MT',
#  'Dubai',
#  'Curlz MT',
#  'Bauhaus 93',
#  'Calibri',
#  'Courier New',
#  'Book Antiqua',
#  'Bodoni MT',
#  'Gill Sans Ultra Bold',
#  'HYSinMyeongJo-Medium',
#  'Georgia',
#  'Lucida Sans Typewriter',
#  'Gadugi',
#  'Bookshelf Symbol 7',
#  'Segoe UI',
#  'Cambria',
#  'Book Antiqua',
#  'Franklin Gothic Heavy',
#  'Kristen ITC',
#  'Palatino Linotype',
#  'Lucida Sans',
#  'Script MT Bold',
#  'Consolas',
#  'Perpetua',
#  'Candara',
#  'Ami R',
#  'Microsoft JhengHei',
#  'Bodoni MT',
#  'MT Extra',
#  'Blackadder ITC',
#  'Lucida Bright',
#  'Bodoni MT',
#  'Footlight MT Light',
#  'Copperplate Gothic Light',
#  'Ink Free',
#  'Lucida Fax',
#  'Courier New',
#  'STSong',
#  'Gill Sans MT Ext Condensed Bold',
#  'Goudy Old Style',
#  'Microsoft Uighur',
#  'Arial',
#  'Dubai',
#  'Dubai',
#  'Tw Cen MT']

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'HYGungso-Bold'  # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac
matplotlib.rcParams['font.size'] = 15   # 글자 크기

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac
matplotlib.rcParams['font.size'] = 15   # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False  # 한글 폰트를 사용시, 마이너스 글자 깨짐현상을 해결

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot([-1,0,1],[-5,-1,2])
